# %%
import pandas as pd
# Out:
# C:\Users\manue\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
dump = pd.read_csv("Dagster/datasets/datadump.csv")

# %%
dump.head(5)
# Out:
#       ID  Sector  Overall Satisfaction with Customer Service in Sector  \
# 0   7784       2                                                  2
# 1   7785       2                                                  5
# 2  27553       1                                                  1
# 3   7812       1                                                  2
# 4   7864       1                                                  5
#
#   Companies with Which Business Was Conducted in the Last 12 Months  \
# 0                                 Globalcom Limited,
# 1                                           9mobile,
# 2                               ACCESS ARM PENSIONS,
# 3                                       ACCESS BANK,
# 4                                       ACCESS BANK,
#
#   Company Interacted with Most Often  Trust (Extent of Satisfaction)  \
# 0                  Globalcom Limited                               3
# 1                            9mobile                               7
# ...

# %%
dump['Region'].isna().sum()
# Out:
# 215

# %%
dump.describe(include='all')
# Out:
#                    i          sect  over_sati_with  \
# count   21387.000000  21387.000000    21387.000000
# unique           NaN           NaN             NaN
# top              NaN           NaN             NaN
# freq             NaN           NaN             NaN
# mean    18485.152663     95.563800        4.630897
# std      6177.610695    221.585014        1.558791
# min      7784.000000      1.000000        1.000000
# 25%     13135.500000      2.000000        4.000000
# 50%     18485.000000      5.000000        5.000000
# 75%     23834.500000      8.000000        6.000000
# max     29182.000000    634.000000        7.000000
#
#                                    comp_with_whic  \
# count                                       21387
# unique                                       3761
# top     MOBILE TELECOMMUNICATIONS NETWORK (MTN) ,
# freq                                         1084
# mean                                          NaN
# ...

# %%
dump.head(10)
# Out:
#       ID  Sector  Overall Satisfaction with Customer Service in Sector  \
# 0   7784       2                                                  2
# 1   7785       2                                                  5
# 2  27553       1                                                  1
# 3   7812       1                                                  2
# 4   7864       1                                                  5
# 5   7927       1                                                  5
# 6   7969       1                                                  5
# 7   7972       1                                                  7
# 8   8007       1                                                  5
# 9   8124       1                                                  6
#
#   Companies with Which Business Was Conducted in the Last 12 Months  \
# 0                                 Globalcom Limited,
# 1                                           9mobile,
# ...

# %%
dump.isnull().sum()
# Out:
# ID                                                                      0
# Sector                                                                  0
# Overall Satisfaction with Customer Service in Sector                    0
# Companies with Which Business Was Conducted in the Last 12 Months       0
# Company Interacted with Most Often                                      6
# Trust (Extent of Satisfaction)                                          0
# Professionalism (Extent of Satisfaction)                                0
# Branches, Branding & Outlook (Extent of Satisfaction)                   0
# Competence (Extent of Satisfaction)                                     0
# Ease of Doing Business (Extent of Satisfaction)                         0
# Processes and Procedures (Extent of Satisfaction)                       0
# Customer-focused Innovations (Extent of Satisfaction)                   0
# Engagement with Customers (Extent of Satisfaction)                   4334
# ...

# %%
len(dump)
# Out:
# 21393
