# %%
import pandas as pd

# %%
dump = pd.read_csv("Dagster/datasets/datadump.csv")

# %%
dump['Age'].unique()
# Out:
# array(['35 - 39', '25 - 29', '40 - 49', '30 - 34', '50 - 59', '18 - 24',
#        'Below 18', '60+'], dtype=object)

# %%
dump.describe(include='all')
# Out:
#                   ID        Sector  \
# count   21393.000000  21393.000000
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean    18485.307344     95.655822
# std      6178.078561    221.677632
# min      7784.000000      1.000000
# 25%     13136.000000      2.000000
# 50%     18485.000000      5.000000
# 75%     23836.000000      8.000000
# max     29182.000000    634.000000
#
#         Overall Satisfaction with Customer Service in Sector  \
# count                                        21393.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# mean                                             4.630720
# std                                              1.558638
# min                                              1.000000
# 25%                                              4.000000
# ...
